# %%
def cylinder_volume(height, radius):        #header
  pi = 3.14159
  return height*pi*radius**2

cylinder_volume(10, 3)
# Out:
# 282.7431

# %% [markdown]
# **def** ----> functions' definition keyword
#
# **cylinder_volume** ----> funactio's name
#
# **(height, radius)** ----> arguments:
#
# -Arguments' names have the same rules of variables' names.
#
# -Arguments are the values that are passed in as inputs when the function is called.
#
# -If the function doesn't take arguments, that just leave the parentheses empty.
#
# -example of function without arguments: (Hello world function)
#
# **code**:
# def print_greetings():
#     print("Hello world!")
#
# -In this case, there is no input data we want to work with the function.
#
# **pi** ----> local variable, meaning that it can only be used within the body of this function. Attemping access outside the function isn't possible.
#
# -This is due to (variable scope) which determines which variables you have access to in python.
#
# **body** ----> operations that the functions do. Within the body we can refer to argument variables and define new variables.
#
# **return** ----> keyword which is used to give back an output value when the function is called. After this keyword, the output of the function is been.
#
# --We can define the output as local variable in the body of the function, then return this variable which is equal to the output as following:

# %%
def cylinder_volume(height, radius):
  pi = 3.14159
  volume = height*pi*radius**2
  return volume

cylinder_volume(10,3)
# Out:
# 282.7431

# %% [markdown]
# - Some of functions like (print) doesn't return anything at all. It only displays the output on the output window(console), but the value it returns is none.
#
# - **None** ----> is when the function will return by default if it doen't explicity return anything else.
#
# **--So now, what is the difference between print and return?**
#
# **print---->** provide output to the console.
#
# **return---->** Provide the value that you can store nd work with and code later.

# %% [markdown]
# ## Print vs. Return in Functions

# %%
# this prints something, but does not return anything
def show_plus_ten(num):
    print(num + 10)

# this returns something, but there is no outout on the console.
def add_ten(num):
    return(num + 10)

print('Calling show_plus_ten...')
return_value_1 = show_plus_ten(5)
print('Done calling')
print('This function returned: {}'.format(return_value_1))

print('\nCalling add_ten...')
return_value_2 = add_ten(5)
print('Done calling')
print('This function returned: {}'.format(return_value_2))
# Out:
# Calling show_plus_ten...
# 15
# Done calling
# This function returned: None
#
# Calling add_ten...
# Done calling
# This function returned: 15

# %% [markdown]
# italicized text##**Default Arguments:**
# They allow functions to use default values when those arguments are omitted.

# %%
def cylinder_volume(height, radius=5):
    pi = 3.14159
    return height * pi * radius ** 2
cylinder_volume(10,5) #We can write it--> cylinder_volume(10) as the radius has a default value which is 5.
cylinder_volume(10,7) #We can also change the radius again and we will not get an error.
#We can pass in arguments with two ways:
cylinder_volume(10, 7) #By position
cylinder_volume(height = 10, radius = 7) #By names
# Out:
# 1539.3791

# %% [markdown]
# #Exercises:

# %% [markdown]
# ***Quiz: Population Density Function***
# Write a function named population_density that takes two arguments, population and land_area, and returns a population density calculated from those values. I've included two test cases that you can use to verify that your function works correctly. Once you've written your function, use the Test Run button to test your code.

# %%
def population_density(population, land_area):
    denisty = population / land_area
    return denisty
# test cases for your function
test1 = population_density(10, 1)
expected_result1 = 10
print("expected result: {}, actual result: {}".format(expected_result1, test1))

test2 = population_density(864816, 121.4)
expected_result2 = 7123.6902801
print("expected result: {}, actual result: {}".format(expected_result2, test2))
# Out:
# expected result: 10, actual result: 10.0
# expected result: 7123.6902801, actual result: 7123.690280065897

# %% [markdown]
# ***Quiz: readable_timedelta***
# Write a function named readable_timedelta. The function should take one argument, an integer days, and return a string that says how many weeks and days that is. For example, calling the function and printing the result like this:
#
# print(readable_timedelta(10))
#
# should output the following:
#
# 1 week(s) and 3 day(s).

# %%
# write your function here
def readable_timedelta(days):
    weeks = days // 7
    remainder = days % 7
    return "{} week(s) and {} day(s).".format(weeks, remainder)
# test your function
print(readable_timedelta(10))
# Out:
# 1 week(s) and 3 day(s).
